# %%
city_name="Toranagallu"
print(f'city_name:{city_name}')
# Out:
# city_name:Toranagallu

# %%
a=int(input("Enter value 1: "))
b=int(input("Enter value 2"))
print(f'The sum of {a} and {b} is: {a+b}')
# Out:
# Enter value 1:  10
# Enter value 2 -5
# The sum of 10 and -5 is: 5

# %%
a=[10,25,12,16,45]
print(f'City_temperatures: {a}')
# Out:
# City_temperatures: [10, 25, 12, 16, 45]

# %%
city={
    "name":"ballari",
    "temperature":42
}
print(f'City_data: {city}')
# Out:
# City_data: {'name': 'ballari', 'temperature': 42}

# %%
city_name, temperature, carbon_footprint="Ballari",42,120.38
print(f'City_name: {city_name},Temperature: {temperature},Carbon_Footprint: {carbon_footprint}')
# Out:
# City_name: Ballari,Temperature: 42,Carbon_Footprint: 120.38
