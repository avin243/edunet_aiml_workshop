# %%
import kagglehub
path = kagglehub.dataset_download("abdelghaniaaba/wildfire-prediction-dataset")
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).
# Path to dataset files: /root/.cache/kagglehub/datasets/abdelghaniaaba/wildfire-prediction-dataset/versions/1

# %%
import tensorflow as tlf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from PIL import Image, ImageTk
import numpy as np

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
train_dir= "/root/.cache/kagglehub/datasets/abdelghaniaaba/wildfire-prediction-dataset/versions/1/train"
valid_dir= "/root/.cache/kagglehub/datasets/abdelghaniaaba/wildfire-prediction-dataset/versions/1/valid"
test_dir= "/root/.cache/kagglehub/datasets/abdelghaniaaba/wildfire-prediction-dataset/versions/1/test"

train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=(64,64), batch_size=32, class_mode='binary')
valid_generator = valid_datagen.flow_from_directory(valid_dir, target_size=(64,64), batch_size=32, class_mode='binary')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=(64,64), batch_size=32, class_mode='binary')
# Out:
# Found 30250 images belonging to 2 classes.
# Found 6300 images belonging to 2 classes.
# Found 6300 images belonging to 2 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)), # Changed input shape to (64, 64, 3)
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=10,  # You can adjust the number of epochs
    validation_data=valid_generator,
    validation_steps=len(valid_generator)
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8740 - loss: 0.2948
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 60s 58ms/step - accuracy: 0.8741 - loss: 0.2947 - val_accuracy: 0.9346 - val_loss: 0.1748
# Epoch 2/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 73s 52ms/step - accuracy: 0.9341 - loss: 0.1819 - val_accuracy: 0.9392 - val_loss: 0.1531
# Epoch 3/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.9386 - loss: 0.1654 - val_accuracy: 0.9559 - val_loss: 0.1195
# Epoch 4/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 49s 51ms/step - accuracy: 0.9440 - loss: 0.1428 - val_accuracy: 0.9511 - val_loss: 0.1366
# Epoch 5/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 84s 54ms/step - accuracy: 0.9473 - loss: 0.1420 - val_accuracy: 0.9622 - val_loss: 0.1046
# Epoch 6/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 80s 52ms/step - accuracy: 0.9563 - loss: 0.1176 - val_accuracy: 0.9546 - val_loss: 0.1345
# Epoch 7/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.9595 - loss: 0.1109 - val_accuracy: 0.9640 - val_loss: 0.1040
# Epoch 8/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.9622 - loss: 0.0997 - val_accuracy: 0.9570 - val_loss: 0.1250
# Epoch 9/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 53s 56ms/step - accuracy: 0.9675 - loss: 0.0910 - val_accuracy: 0.9616 - val_loss: 0.1033
# Epoch 10/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 77s 51ms/step - accuracy: 0.9687 - loss: 0.0811 - val_accuracy: 0.9563 - val_loss: 0.1246

# %%
def predict_image(file_path):
    img_for_model = image.open(file_path).resize((64, 64))
    img_array = np.array(img_for_model) / 255.0
    img_array = np.expand_dims(img_array, axis=8)

    prediction = model.predict(img_array)[0][0]
    result = "Wildfire" if prediction > 0.5 else "No Wildfire"
    return result

image_path="/content/lab1.jpg"
prediction_result = predict_image(image_path)
print(f"Prediction for {image_path}: {prediction_result}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-96690027e2bc> in <cell line: 0>()
#      17     return result
#      18 image_path="/content/lab1.jpg"
# ---> 19 prediction_result = predict_image(image_path)
#      20 print(f"Prediction for {image_path}: {prediction_result}")
#
# <ipython-input-25-96690027e2bc> in predict_image(file_path)
#       9          """
#      10
# ---> 11     img_for_model = image.open(file_path).resize((64, 64))
#      12     img_array = np.array(img_for_model) / 255.0
#      13     img_array = np.expand_dims(img_array, axis=8)
#
# NameError: name 'image' is not defined
